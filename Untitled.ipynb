# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
# %matplotlib inline
RADIUS=21

# %%
im1 = r"/mnt/c/Users/James/test_camera_pics/set2/img2021-07-08_11:13:56.398610.jpg"
im2 = r"/mnt/c/Users/James/test_camera_pics/set2/img2021-07-08_16:04:40.879080.jpg"

# %%
image1 = cv2.imread(im1)
orig1 = image1.copy()
gray1 = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)
image2 = cv2.imread(im2)
orig2 = image2.copy()
gray2 = cv2.cvtColor(image2, cv2.COLOR_BGR2GRAY)

# %%
# apply a Gaussian blur to the image then find the brightest
# region
gray1 = cv2.GaussianBlur(gray1, (RADIUS, RADIUS), 0)
(minVal1, maxVal1, minLoc1, maxLoc1) = cv2.minMaxLoc(gray1)
cv2.circle(image1, maxLoc1, RADIUS, (255, 0, 0), 2)
plt.imshow(image1)
plt.show()

# %%
gray2 = cv2.GaussianBlur(gray2, (RADIUS, RADIUS), 0)
(minVal2, maxVal2, minLoc2, maxLoc2) = cv2.minMaxLoc(gray2)
cv2.circle(image2, maxLoc2, RADIUS, (255, 0, 0), 2)
plt.imshow(image2)
plt.show()

# %%
cv2.imwrite('red_led.jpg', image1)
cv2.imwrite('grn_led.jpg', image2)
# Out:
# True
